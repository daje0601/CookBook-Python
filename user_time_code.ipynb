# %% [markdown]
# <a href="https://colab.research.google.com/github/daje0601/pandas_study/blob/main/user_time_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\user\Documents\pandas_study\data_example\2103_use_time - time.csv", index_col=0)
df
# Out:
#           pandas  python  ML  read_book  health  Meal  etc  active_time  \
# date
# 21.03.01       0     3.0   0          1     0.0     2   13         19.0
# 21.03.02       0    13.5   0          1     1.5     2    0         18.0
# 21.03.03       0    13.0   0          1     1.5     2    0         17.5
# 21.03.04       0    13.0   0          1     1.5     2    0         17.5
# 21.03.05       0    13.0   0          1     1.5     2    0         17.5
# 21.03.06       0    13.0   0          1     1.5     2    0         17.5
# 21.03.07       0     6.0   0          1     1.5     2    9         19.5
# 21.03.08       0    13.5   0          1     1.5     2    0         18.0
# 21.03.09       0    13.0   0          1     1.5     2    0         17.5
# 21.03.10       0     7.0   0          1     1.5     2    0         11.5
# 21.03.11       0     8.0   0          1     1.5     2    0         12.5
# 21.03.12       0    13.0   0          1     1.5     2    0         17.5
# ...

# %%
df=df[7:14]

# %%
columns_sum = df.sum()
df.loc["11week"] = columns_sum
df
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#           pandas  python   ML  read_book  health  Meal  etc  active_time  \
# date
# 21.03.08     0.0    13.5  0.0        1.0     1.5   2.0  0.0         18.0
# 21.03.09     0.0    13.0  0.0        1.0     1.5   2.0  0.0         17.5
# 21.03.10     0.0     7.0  0.0        1.0     1.5   2.0  0.0         11.5
# 21.03.11     0.0     8.0  0.0        1.0     1.5   2.0  0.0         12.5
# 21.03.12     0.0    13.0  0.0        1.0     1.5   2.0  0.0         17.5
# 21.03.13     0.0    12.0  0.0        1.0     1.5   2.0  0.0         16.5
# 21.03.14     0.0     4.0  0.0        1.0     1.5   2.0  9.0         17.5
# ...

# %%
df = df.drop(columns = ["active_time", "sleep_time", "total_time"])

# %%
df.loc["11week"].plot(kind="pie", autopct="%0.1f%%", figsize=(6,6), wedgeprops={"alpha":0.4});

# %%
df=df[7:]

# %%
columns_sum = df.sum()
df.loc["sum"] = columns_sum
df
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#        pandas  python   ML  read_book  health  Meal   etc
# date
# March     0.0    74.5  0.0        7.0     9.0  14.0  22.0
# sum       0.0    74.5  0.0        7.0     9.0  14.0  22.0

# %%
df = df.drop(columns = ["active_time", "sleep_time", "total_time"])
df.loc["5week"].plot(kind="pie", autopct="%0.1f%%", figsize=(6,6), wedgeprops={"alpha":0.5});
